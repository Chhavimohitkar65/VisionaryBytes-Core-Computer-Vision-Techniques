# %%
import cv2                                     #used in performing image operations
import matplotlib
from matplotlib import pyplot as plt           # pyplot to display images
import PIL as pillow                           # pillow and  numpy to work with img and matrix
import numpy as np

# %%
img = cv2.imread('photos\cartoon.jpeg')
plt.imshow(img)

# %%
contrast_image = cv2.bitwise_not(img)
plt.imshow(contrast_image)
cv2.imwrite('photos\output.jpeg', contrast_image)
# Out:
# True

# %%
#to check how arithmatic operator actually change the contrast

from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

im_1 = Image.open("photos\cartoon.jpeg")
plt.imshow(im_1)
ar_1 = Array(im_1)
ar_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       7 im_1 = Image.open("photos\cartoon.jpeg")
#       8 plt.imshow(im_1)
# ----> 9 ar_1 = array(im_1)
#      10 ar_1
#
# NameError: name 'array' is not defined
